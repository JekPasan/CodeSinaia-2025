# %%
import matplotlib.pyplot as plt
from random import randint

# %%
class Val():
    def __init__(self, val: int, freq: int = 0, positions: list = []):
        self.val = val
        self.freq = freq
        self.positions = positions
    
    def increment(self, pos: int):
        self.freq += 1
        self.positions.append(pos)

# %%
vals = {}
vals_list = []
count = int(input("Enter the number of random values to generate: "))
min_val = int(input("Enter the minimum value: "))
max_val = int(input("Enter the maximum value: "))
it = 0

# %%
while it < count:
    i = randint(min_val, max_val)
    vals_list.append(i)
    if i not in vals:
        vals[i] = Val(i, 1, [it])
    else:
        vals[i].increment(it)
    it += 1

file = open("randoms_db.txt", "w")
for key in vals.keys():
    file.write(f"{vals[key].val}: {vals[key].positions}\n")
file.close()

# %% [markdown]
# ### numarul de valori unice

# %%
print(f"Number of unique values: {len(vals)}")
# Out:
# Number of unique values: 63

# %% [markdown]
# ### aflam minimul si maximul

# %%
print(f"Minimum value: {min(vals.keys())}")
print(f"Maximum value: {max(vals.keys())}")
# Out:
# Minimum value: 1
# Maximum value: 100

# %% [markdown]
# ### aflam valoarea mediana

# %%
sorted_vals = sorted(vals.keys())
if len(sorted_vals) % 2 == 1:
    median = sorted_vals[len(sorted_vals) // 2]
else:
    median = (sorted_vals[len(sorted_vals) // 2] + sorted_vals[len(sorted_vals) // 2 + 1]) / 2
print(median)
# Out:
# 54

# %% [markdown]
# ### aflam valoarea medie

# %%
sum = 0
cnt = 0
for key in vals.keys():
    cnt += vals[key].freq
    sum += vals[key].val * vals[key].freq
medie = sum/cnt if cnt > 0 else 0
print(medie)
# Out:
# 51.12

# %% [markdown]
# ### aflam deviatia standard

# %%
sum = 0
for key in vals.keys():
    sum += vals[key].freq * (vals[key].val - medie) ** 2
deviation = (sum / cnt) ** 0.5 if cnt > 0 else 0
print(deviation)
# Out:
# 29.100268040002657

# %% [markdown]
# ### generam un grafic cu bare

# %%
fig, ax = plt.subplots()
ax.bar(vals.keys(), [vals[key].freq for key in vals.keys()], color='orange')
plt.show()

# %% [markdown]
# ### generam un grafic cu plots

# %%
print(vals_list)
plt.figure(figsize=(10, 8))
plt.plot(vals_list, marker='o', linestyle='-', color='red')
plt.xticks(range(0, 101, 1))
plt.yticks(range(0, 101, 1))
plt.show()
# Out:
# [16, 13, 38, 50, 73, 86, 20, 5, 49, 27, 31, 79, 80, 38, 20, 72, 21, 58, 1, 74, 22, 3, 87, 94, 59, 87, 65, 70, 81, 21, 36, 65, 12, 72, 44, 95, 64, 50, 94, 49, 11, 29, 100, 85, 72, 49, 90, 46, 68, 97, 74, 90, 55, 46, 18, 65, 15, 51, 71, 11, 77, 60, 78, 15, 77, 51, 18, 5, 54, 58, 85, 61, 24, 27, 41, 85, 96, 6, 29, 83, 81, 53, 48, 18, 85, 32, 12, 17, 22, 73, 98, 87, 4, 8, 57, 16, 75, 72, 57, 3]
